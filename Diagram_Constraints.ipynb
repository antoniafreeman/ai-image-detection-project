# %% [markdown]
# <a href="https://colab.research.google.com/github/antoniafreeman/ai-image-detection-project/blob/main/Diagram_Constraints.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Isometric_Images = '/content/drive/MyDrive/ground_truth/Or'

# %%
Non_Isometric = '/content/drive/MyDrive/diag'

# %%
from glob import glob
import cv2
import numpy as np

# %%
Isometric_Images = glob(Isometric_Images+'/*')

# %%
Non_Isometric = glob(Non_Isometric+'/*')

# %%
Non_Isometric
# Out:
# ['/content/drive/MyDrive/diag/1.PNG',
#  '/content/drive/MyDrive/diag/2.PNG',
#  '/content/drive/MyDrive/diag/3.PNG',
#  '/content/drive/MyDrive/diag/4.PNG',
#  '/content/drive/MyDrive/diag/5.PNG',
#  '/content/drive/MyDrive/diag/6.PNG']

# %%
Isometric_Image = []
for i in Isometric_Images:
  img = cv2.imread(i,0)
  img = cv2.resize(img,(224,224))
  Isometric_Image.append(img)

# %%
Non_Isometric_Img = []
for i in Non_Isometric:
  img = cv2.imread(i,0)
  img = cv2.resize(img,(224,224))
  Non_Isometric_Img.append(img)

# %%
Isometric_Image = np.asarray(Isometric_Image)

# %%
Non_Isometric = np.asarray(Non_Isometric_Img)

# %%
Isometric_Image = np.expand_dims(Isometric_Image,axis=-1)

# %%
Non_Isometric = np.expand_dims(Non_Isometric,axis=-1)

# %%
Isometric_Image = Isometric_Image/255.0

# %%
Non_Isometric = Non_Isometric/255.0

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(Isometric_Image[0],cmap='gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #**Model**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_unet(input_shape):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    x1 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
    x1 = layers.BatchNormalization()(x1)
    x1 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x1)
    x1 = layers.BatchNormalization()(x1)
    p1 = layers.MaxPooling2D((2, 2))(x1)
    p1 = layers.Dropout(0.1)(p1)  # Dropout after pooling

    x2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(p1)
    x2 = layers.BatchNormalization()(x2)
    x2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x2)
    x2 = layers.BatchNormalization()(x2)
    p2 = layers.MaxPooling2D((2, 2))(x2)
    p2 = layers.Dropout(0.1)(p2)  # Dropout after pooling

    x3 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p2)
    x3 = layers.BatchNormalization()(x3)
    x3 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x3)
    x3 = layers.BatchNormalization()(x3)
    p3 = layers.MaxPooling2D((2, 2))(x3)
    p3 = layers.Dropout(0.1)(p3)  # Dropout after pooling

    x4 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p3)
    x4 = layers.BatchNormalization()(x4)
    x4 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x4)
    x4 = layers.BatchNormalization()(x4)

    # Decoder
    u4 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x4)
    u4 = layers.concatenate([u4, x3])
    x5 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u4)
    x5 = layers.BatchNormalization()(x5)
    x5 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x5)
    x5 = layers.BatchNormalization()(x5)
    x5 = layers.Dropout(0.1)(x5)  # Dropout after Conv layers

    u5 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x5)
    u5 = layers.concatenate([u5, x2])
    x6 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u5)
    x6 = layers.BatchNormalization()(x6)
    x6 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x6)
    x6 = layers.BatchNormalization()(x6)
    x6 = layers.Dropout(0.1)(x6)  # Dropout after Conv layers

    u6 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(x6)
    u6 = layers.concatenate([u6, x1])
    x7 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(u6)
    x7 = layers.BatchNormalization()(x7)
    x7 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x7)
    x7 = layers.BatchNormalization()(x7)
    x7 = layers.Dropout(0.1)(x7)  # Dropout after Conv layers

    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(x7)

    model = models.Model(inputs, outputs)
    return model

input_shape = (224, 224, 1)  # Grayscale input
autoencoder = build_unet(input_shape)
autoencoder.compile(optimizer='adam', loss='MSE')
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 224, 224, 16)   │            160 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 224, 224, 16)   │             64 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 224, 224, 16)   │          2,320 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 224, 224, 16)   │             64 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 112, 112, 16)   │              0 │ batch_normalization_1… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 112, 112, 16)   │              0 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 112, 112, 32)   │          4,640 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 112, 112, 32)   │            128 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 112, 112, 32)   │          9,248 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 112, 112, 32)   │            128 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 56, 56, 32)     │              0 │ batch_normalization_3… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 56, 56, 32)     │              0 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 56, 56, 64)     │         18,496 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 56, 56, 64)     │            256 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 56, 56, 64)     │         36,928 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 56, 56, 64)     │            256 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 28, 28, 64)     │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 28, 28, 64)     │              0 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 28, 28, 128)    │         73,856 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 28, 28, 128)    │            512 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 28, 28, 128)    │        147,584 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 28, 28, 128)    │            512 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 56, 56, 128)    │         65,664 │ batch_normalization_7… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 56, 56, 192)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 56, 56, 64)     │        110,656 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 56, 56, 64)     │            256 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 56, 56, 64)     │         36,928 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 56, 56, 64)     │            256 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 56, 56, 64)     │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 112, 112, 64)   │         16,448 │ dropout_3[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 112, 112, 96)   │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 112, 112, 32)   │         27,680 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 112, 112, 32)   │            128 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 112, 112, 32)   │          9,248 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 112, 112, 32)   │            128 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 112, 112, 32)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 224, 224, 32)   │          4,128 │ dropout_4[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 224, 224, 48)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 224, 224, 16)   │          6,928 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 224, 224, 16)   │             64 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 224, 224, 16)   │          2,320 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 224, 224, 16)   │             64 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 224, 224, 16)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 224, 224, 1)    │             17 │ dropout_5[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 576,065 (2.20 MB)
#  Trainable params: 574,657 (2.19 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
history=autoencoder.fit(Isometric_Image,Isometric_Image, epochs=100, batch_size=4, validation_split=0.1)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 33s 412ms/step - loss: 0.2604 - val_loss: 0.2011
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1855 - val_loss: 0.1610
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1519 - val_loss: 0.1322
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1346 - val_loss: 0.1060
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1211 - val_loss: 0.0830
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1094 - val_loss: 0.0659
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0994 - val_loss: 0.0539
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0924 - val_loss: 0.0442
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0875 - val_loss: 0.0390
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0835 - val_loss: 0.0359
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0760 - val_loss: 0.0310
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0763 - val_loss: 0.0277
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0661 - val_loss: 0.0251
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0614 - val_loss: 0.0235
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0586 - val_loss: 0.0214
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0549 - val_loss: 0.0209
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0515 - val_loss: 0.0204
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0476 - val_loss: 0.0192
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0440 - val_loss: 0.0187
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0414 - val_loss: 0.0183
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0395 - val_loss: 0.0184
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0355 - val_loss: 0.0184
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0318 - val_loss: 0.0183
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0318 - val_loss: 0.0183
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0292 - val_loss: 0.0182
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0269 - val_loss: 0.0169
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0247 - val_loss: 0.0165
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0240 - val_loss: 0.0168
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0206 - val_loss: 0.0174
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0192 - val_loss: 0.0180
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0178 - val_loss: 0.0182
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0160 - val_loss: 0.0186
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0197 - val_loss: 0.0183
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0192 - val_loss: 0.0190
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0169 - val_loss: 0.0182
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0169 - val_loss: 0.0192
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0168 - val_loss: 0.0172
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0147 - val_loss: 0.0198
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0136 - val_loss: 0.0204
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0125 - val_loss: 0.0164
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0112 - val_loss: 0.0191
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0125 - val_loss: 0.0192
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0112 - val_loss: 0.0193
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0100 - val_loss: 0.0195
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0104 - val_loss: 0.0198
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0102 - val_loss: 0.0200
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0096 - val_loss: 0.0200
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0077 - val_loss: 0.0201
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0093 - val_loss: 0.0202
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0073 - val_loss: 0.0201
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0079 - val_loss: 0.0202
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0078 - val_loss: 0.0202
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0074 - val_loss: 0.0201
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0079 - val_loss: 0.0203
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0075 - val_loss: 0.0199
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0068 - val_loss: 0.0195
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0061 - val_loss: 0.0197
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0058 - val_loss: 0.0197
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0056 - val_loss: 0.0198
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0059 - val_loss: 0.0201
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0052 - val_loss: 0.0199
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0047 - val_loss: 0.0192
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0051 - val_loss: 0.0196
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0065 - val_loss: 0.0192
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0081 - val_loss: 0.0198
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0065 - val_loss: 0.0150
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0067 - val_loss: 0.0163
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0059 - val_loss: 0.0169
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0058 - val_loss: 0.0165
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0053 - val_loss: 0.0160
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0051 - val_loss: 0.0173
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0050 - val_loss: 0.0172
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0041 - val_loss: 0.0162
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0046 - val_loss: 0.0169
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0052 - val_loss: 0.0162
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0039 - val_loss: 0.0148
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0042 - val_loss: 0.0162
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0042 - val_loss: 0.0163
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0040 - val_loss: 0.0159
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0037 - val_loss: 0.0144
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0039 - val_loss: 0.0137
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0035 - val_loss: 0.0148
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0036 - val_loss: 0.0137
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0031 - val_loss: 0.0146
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0035 - val_loss: 0.0152
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0036 - val_loss: 0.0129
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0041 - val_loss: 0.0129
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0032 - val_loss: 0.0097
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0042 - val_loss: 0.0141
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0037 - val_loss: 0.0131
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0030 - val_loss: 0.0117
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0031 - val_loss: 0.0094
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0027 - val_loss: 0.0123
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0034 - val_loss: 0.0125
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0029 - val_loss: 0.0111
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0032 - val_loss: 0.0100
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0024 - val_loss: 0.0104
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0023 - val_loss: 0.0099
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0024 - val_loss: 0.0113

# %%
# prompt: plot MSE loss

import matplotlib.pyplot as plt

# Extract loss values from the history object
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plot the training and validation loss
epochs = range(1, len(training_loss) + 1)
plt.plot(epochs, training_loss, 'b', label='Training Loss')
plt.plot(epochs, validation_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss (MSE)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.imshow(Isometric_Image[20],cmap='gray')

# %%
# prompt: export the model

autoencoder.save('/content/drive/MyDrive/Diagrams.v2i.yolov8/anomaly/anomaly.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
autoencoder.save('/content/drive/MyDrive/Diagrams.v2i.yolov8/anomaly/anomaly.keras')

# %%
# prompt: save model weights

autoencoder.save_weights('/content/drive/MyDrive/Diagrams.v2i.yolov8/anomaly/anomaly_weight.weights.h5')

# %%
img = autoencoder.predict(np.expand_dims(Isometric_Image[20],axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
import numpy as np

# Assuming 'autoencoder' is your trained model and 'X_test' is your test dataset
reconstructed_images = autoencoder.predict(np.expand_dims(Non_Isometric[3],axis=0))

# Calculate reconstruction errors (e.g., Mean Squared Error)
def calculate_reconstruction_error(original, reconstructed):
    return np.mean(np.square(original - reconstructed), axis=(1, 2, 3))  # Assuming 4D images (batch_size, width, height, channels)

reconstruction_errors = calculate_reconstruction_error(Non_Isometric[3], reconstructed_images)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
print("Reconstruction Error :", reconstruction_errors)
# Out:
# Reconstruction Error : [0.00395006]

# %%
final_dataset = np.concatenate((Isometric_Image,Non_Isometric),axis=0)

# %%
isometric_label = np.zeros((len(Isometric_Image),1))

# %%
non_isometric_label = np.ones((len(Non_Isometric),1))

# %%
final_labels =  np.concatenate((isometric_label,non_isometric_label),axis=0)

# %%
import numpy as np

# Assuming 'autoencoder' is your trained model and 'X_test' is your test dataset
reconstructed_images = autoencoder.predict(final_dataset)

# Calculate reconstruction errors (e.g., Mean Squared Error)
def calculate_reconstruction_error(original, reconstructed):
    return np.mean(np.square(original - reconstructed), axis=(1, 2, 3))  # Assuming 4D images (batch_size, width, height, channels)

reconstruction_errors = calculate_reconstruction_error(final_dataset, reconstructed_images)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step

# %%
# prompt: plot the distribution of errors

import matplotlib.pyplot as plt

# Plot the distribution of reconstruction errors
plt.hist(reconstruction_errors, bins=50)
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.title('Distribution of Reconstruction Errors')
plt.show()

# %%
# Set a threshold for anomaly detection
threshold = np.percentile(reconstruction_errors, 85)  # Example: Top 5% as anomaly

# Label as 1 (anomaly) if reconstruction error > threshold, else 0 (normal)
anomaly_labels = (reconstruction_errors > threshold).astype(int)

# %%
print(threshold)
# Out:
# 0.014581064133542713

# %%
len(anomaly_labels)
# Out:
# 38

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Assuming y_true contains the true labels (0 for normal, 1 for anomalies)
accuracy = accuracy_score(final_labels, anomaly_labels)
precision = precision_score(final_labels, anomaly_labels)
recall = recall_score(final_labels, anomaly_labels)
f1 = f1_score(final_labels, anomaly_labels)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1-Score: {f1}')
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(final_labels, reconstruction_errors)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f'ROC Curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Assuming 'final_labels' are your true labels and 'anomaly_labels' are the predicted labels
cm = confusion_matrix(final_labels, anomaly_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Non-Anomaly (0)', 'Anomaly (1)'],
            yticklabels=['Non-Anomaly (0)', 'Anomaly (1)'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
